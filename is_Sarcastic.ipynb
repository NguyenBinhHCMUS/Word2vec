# %% [markdown]
# #### Mục tiêu: Xây dựng mô hình có độ chính xác trên tập validation khoảng 84%

# %%
import json
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json \
    -O /tmp/sarcasm.json
# Out:
# --2020-09-18 06:29:35--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.13.128, 74.125.206.128, 64.233.167.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.13.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/tmp/sarcasm.json’
#
# /tmp/sarcasm.json   100%[===================>]   5.38M  --.-KB/s    in 0.08s
#
# 2020-09-18 06:29:35 (64.5 MB/s) - ‘/tmp/sarcasm.json’ saved [5643545/5643545]

# %%
with open("/tmp/sarcasm.json", 'r') as f:
    datastore = json.load(f)

sentences = []
labels = []

for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])


import numpy as np
labels = np.array(labels)

# %%
# Chia features tập train
training_sentences = sentences[0:training_size]
# FIXME: Chia features tập test
test_sentences = sentences[training_size:]
# FIXME: Chia labels tập train
train_labels = labels[0:training_size]
# FIXME: Chia labels tập test
test_labels = labels[training_size:]

# %%
# FIXME: Tạo tokenizer
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# FIXME: Đưa từ vào tokenizer để tạo từ điển

tokenizer.fit_on_texts(training_sentences)

# FIXME: Biến các câu train thành sequences

training_sequences = tokenizer.texts_to_sequences(training_sentences)

# FIXME: Padding cho các train sequences

training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# FIXME: Biến các câu test thành sequences và padding tương ứng

test_sequences = tokenizer.texts_to_sequences(test_sentences)

test_padded = pad_sequences(test_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
# Xây dựng model

# FIXME: Tạo model Sequential

model = Sequential()

# FIXME: Thêm một lớp Embedding

model.add(Embedding(vocab_size, embedding_dim, input_length= max_length))

#Fix

model.add(GlobalAveragePooling1D())

# FIXME: Thêm một lớp Dense, chú ý có activation

model.add(Dense(10, activation='relu'))

# FIXME: Thêm một lớp Dense cuối, chú ý có activation

model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 16)           160000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                170
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 160,181
# Trainable params: 160,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# FIXME: Compile Optimizer và Loss function

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# %%
# FIXME: Tiến hành training

model.fit(training_padded, train_labels, epochs=30, validation_data=(test_padded, test_labels))
# Out:
# Epoch 1/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.6861 - acc: 0.5588 - val_loss: 0.6809 - val_acc: 0.5633
# Epoch 2/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.6242 - acc: 0.6571 - val_loss: 0.5171 - val_acc: 0.8080
# Epoch 3/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.4151 - acc: 0.8432 - val_loss: 0.3921 - val_acc: 0.8387
# Epoch 4/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3284 - acc: 0.8708 - val_loss: 0.3678 - val_acc: 0.8426
# Epoch 5/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.2879 - acc: 0.8880 - val_loss: 0.3502 - val_acc: 0.8523
# Epoch 6/30
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2588 - acc: 0.9004 - val_loss: 0.3433 - val_acc: 0.8548
# Epoch 7/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.2362 - acc: 0.9097 - val_loss: 0.3392 - val_acc: 0.8571
# Epoch 8/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.2160 - acc: 0.9179 - val_loss: 0.3398 - val_acc: 0.8565
# Epoch 9/30
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1991 - acc: 0.9248 - val_loss: 0.3421 - val_acc: 0.8560
# Epoch 10/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.1840 - acc: 0.9323 - val_loss: 0.3475 - val_acc: 0.8550
# Epoch 11/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.1712 - acc: 0.9371 - val_loss: 0.3536 - val_acc: 0.8541
# Epoch 12/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.1592 - acc: 0.9420 - val_loss: 0.3623 - val_acc: 0.8547
# Epoch 13/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.1479 - acc: 0.9478 - val_loss: 0.3727 - val_acc: 0.8548
# Epoch 14/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.1386 - acc: 0.9515 - val_loss: 0.3831 - val_acc: 0.8514
# Epoch 15/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.1304 - acc: 0.9553 - val_loss: 0.4006 - val_acc: 0.8468
# Epoch 16/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.1221 - acc: 0.9581 - val_loss: 0.4039 - val_acc: 0.8518
# Epoch 17/30
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1145 - acc: 0.9619 - val_loss: 0.4170 - val_acc: 0.8514
# Epoch 18/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.1076 - acc: 0.9647 - val_loss: 0.4346 - val_acc: 0.8486
# Epoch 19/30
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1013 - acc: 0.9664 - val_loss: 0.4552 - val_acc: 0.8425
# Epoch 20/30
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0959 - acc: 0.9683 - val_loss: 0.4607 - val_acc: 0.8477
# Epoch 21/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.0900 - acc: 0.9718 - val_loss: 0.4789 - val_acc: 0.8436
# Epoch 22/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0851 - acc: 0.9733 - val_loss: 0.5021 - val_acc: 0.8387
# Epoch 23/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0804 - acc: 0.9741 - val_loss: 0.5128 - val_acc: 0.8392
# Epoch 24/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.0756 - acc: 0.9765 - val_loss: 0.5303 - val_acc: 0.8369
# Epoch 25/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.0706 - acc: 0.9780 - val_loss: 0.5488 - val_acc: 0.8369
# Epoch 26/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.0671 - acc: 0.9796 - val_loss: 0.5687 - val_acc: 0.8356
# Epoch 27/30
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0634 - acc: 0.9805 - val_loss: 0.5913 - val_acc: 0.8338
# Epoch 28/30
# 625/625 [==============================] - 3s 6ms/step - loss: 0.0605 - acc: 0.9822 - val_loss: 0.6130 - val_acc: 0.8348
# Epoch 29/30
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0565 - acc: 0.9839 - val_loss: 0.6322 - val_acc: 0.8310
# Epoch 30/30
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0534 - acc: 0.9841 - val_loss: 0.6554 - val_acc: 0.8293

# %%
# FIXME: Tiến hành dự đoán

# %%
test_sen = ["Everyone seems normal until you get to know them."]

# FIXME: Chuyển câu thành Sequences

test_seq = tokenizer.texts_to_sequences(test_sen)

# FIXME: padding cho câu này

padded_predict = pad_sequences(test_seq, maxlen=max_length, padding=padding_type, truncating=trunc_type)
# FIXME: Tiến hành dự đoán

model.predict(padded_predict)
# Out:
# array([[0.99477166]], dtype=float32)
